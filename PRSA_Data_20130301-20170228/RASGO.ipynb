# %% [markdown]
# https://www.rasgoml.com/feature-engineering-tutorials/how-to-create-time-series-features-with-tsfresh

# %%
import pandas as pd
import os

# Directory containing the CSV files
data_dir = 'PRSA_Data_20130301-20170228'

# Collect all the dataframes to be concatenated
dfs = []
for file in os.listdir(data_dir):
    if file.endswith('.csv'):
        dfs.append(pd.read_csv(os.path.join(data_dir, file)))

# Concatenate them together
df = pd.concat(dfs, ignore_index=True)

df['timestamp'] = pd.to_datetime(df[["year", "month", "day", "hour"]])
df.drop(columns=['No'], inplace=True)
df.sort_values(by=['timestamp', 'station']).head(10)
# Out:
#         year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0       2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 35064   2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 70128   2013      3    1     0    4.0   4.0   3.0   NaN  200.0  82.0  -2.3
# 105192  2013      3    1     0    9.0   9.0   3.0  17.0  300.0  89.0  -0.5
# 140256  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 175320  2013      3    1     0    6.0  18.0   5.0   NaN  800.0  88.0   0.1
# 210384  2013      3    1     0    7.0   7.0   3.0   2.0  100.0  91.0  -2.3
# 245448  2013      3    1     0    5.0  14.0   4.0  12.0  200.0  85.0  -0.5
# 280512  2013      3    1     0    3.0   6.0   3.0   8.0  300.0  44.0  -0.9
# 315576  2013      3    1     0    6.0   6.0   4.0   8.0  300.0  81.0  -0.5
#
#           PRES  DEWP  RAIN   wd  WSPM       station  timestamp
# 0       1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin 2013-03-01
# 35064   1020.8 -19.7   0.0    E   0.5     Changping 2013-03-01
# 70128   1020.8 -19.7   0.0    E   0.5      Dingling 2013-03-01
# 105192  1024.5 -21.4   0.0  NNW   5.7        Dongsi 2013-03-01
# 140256  1023.0 -18.8   0.0  NNW   4.4      Guanyuan 2013-03-01
# 175320  1021.1 -18.6   0.0   NW   4.4       Gucheng 2013-03-01
# 210384  1020.3 -20.7   0.0  WNW   3.1       Huairou 2013-03-01
# 245448  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan 2013-03-01
# 280512  1025.8 -20.5   0.0   NW   9.3        Shunyi 2013-03-01
# 315576  1024.5 -21.4   0.0  NNW   5.7       Tiantan 2013-03-01
